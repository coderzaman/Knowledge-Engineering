# %% [markdown]
# <a href="https://colab.research.google.com/github/coderzaman/Knowledge-Engineering/blob/master/Unidirected_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Create Graph**

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()

# %% [markdown]
# **Adding nodes to the graph**

# %% [markdown]
# 1. Add a single node

# %%
G.add_node('A')

# Draw the graph
nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# 2. Add multiple nodes from a list

# %%
G.add_nodes_from(['B', 'C', 'D', 'E'])

nx.draw(G, with_labels=True)

# %% [markdown]
# **Adding edges to the graph**

# %% [markdown]
# 1. Add a single edge (nodes 'B' and 'C' already exist)

# %%
G.add_edge('B', 'C')
nx.draw(G, with_labels=True)

# %% [markdown]
# 3. Add multiple edges from a list of tuples

# %%
G.add_edges_from([('A', 'B'), ('C', 'D'), ('A', 'D'), ('A', 'A'), ('C', 'A')])
nx.draw(G, with_labels=True)

# %% [markdown]
# **Fetch Graph Information**

# %% [markdown]
# 1. Nodes and Edges in a Graph

# %%
print("Nodes:", G.nodes())
print("Edges:", G.edges())
# Out:
# Nodes: ['A', 'B', 'C', 'D', 'E']
# Edges: [('A', 'B'), ('A', 'D'), ('A', 'A'), ('A', 'C'), ('B', 'C'), ('C', 'D')]

# %% [markdown]
# 2. No of Nodes and Edges in a Graph

# %%
print("No of Nodes:", G.number_of_nodes())
print("No of Edges:", G.number_of_edges())
# Out:
# No of Nodes: 5
# No of Edges: 6

# %% [markdown]
# 3. List of Nodes and Edges in a graph

# %%
print("List of nodes:", list(G.nodes()))
print("List of edges:", list(G.edges()))
# Out:
# List of nodes: ['A', 'B', 'C', 'D', 'E']
# List of edges: [('A', 'B'), ('A', 'D'), ('A', 'A'), ('A', 'C'), ('B', 'C'), ('C', 'D')]

# %% [markdown]
# 4. Degree of any vertex of graph

# %%
print("Degree of A:", G.degree['A'])
# Out:
# Degree of A: 5

# %% [markdown]
# **Removing nodes from a graph**

# %%
G = nx.wheel_graph(5)
nx.draw(G, with_labels=True)

# %%
print("Original Graph:")
print("Nodes:", G.nodes())
print("Edges:", G.edges())
# Out:
# Original Graph:
# Nodes: [0, 1, 2, 3, 4]
# Edges: [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 4), (2, 3), (3, 4)]

# %% [markdown]
# 1. Remove node n.
#
#   Removes the node n and all adjacent edges. Attempting to remove a nonexistent node will raise an exception.

# %%
G.remove_node(0)
nx.draw(G, with_labels=True)

# %% [markdown]
# 2. Graph.remove_nodes_from(nodes)
#
#     Remove multiple nodes.

# %%
G.remove_nodes_from([1, 2])
nx.draw(G, with_labels=True)

# %% [markdown]
# **Removing edges from a graph**

# %%
G.clear()
G.add_edges_from([('A', 'B'), ('C', 'D'), ('A', 'D'), ('A', 'A'), ('C', 'A')])
nx.draw(G, with_labels=True)

# %%
print(list(G.nodes()))
print(list(G.edges()))
# Out:
# ['A', 'B', 'C', 'D']
# [('A', 'B'), ('A', 'D'), ('A', 'A'), ('A', 'C'), ('C', 'D')]

# %% [markdown]
# 1. Remove Sigle edge(Graph.remove_edge)
#
#     Graph.remove_edge(u, v)
#
#     u, v: nodes
#
#         Remove the edge between nodes u and v.

# %%
G.remove_edge('A','B')
nx.draw(G, with_labels=True)

# %% [markdown]
# 2. Remove Multiple edges(Graph.remove_edge)

# %%
G.remove_edges_from([('A','A'), ('A','D')])
nx.draw(G, with_labels=True)

# %%
G.clear()
G.add_nodes_from(['A', 'B', 'C', 'D', 'E'])
G.add_edges_from([('A', 'B'), ('C', 'D'), ('A', 'D'), ('A', 'A'), ('C', 'A')])

nx.draw(G, with_labels=True)

# %% [markdown]
# **Connected Components**

# %% [markdown]
# 1. Count the number of connected components

# %%
num_components = nx.number_connected_components(G)
print(f"Number of connected components: {num_components}")
# Out:
# Number of connected components: 2

# %% [markdown]
# 2. Get the actual list of nodes in each component

# %%
components = list(nx.connected_components(G))
print(list(components[0]))
print(list(components[1]))
# Out:
# ['B', 'D', 'A', 'C']
# ['E']

# %%
G.clear()

# %% [markdown]
# **Subgraph**

# %% [markdown]
#  1. Create the main graph (G)

# %%
G = nx.Graph()
G.add_edges_from([
    ('A', 'B'), ('A', 'C'), ('A', 'D'),
    ('B', 'C'), ('C', 'D')
])

nx.draw(G, with_labels=True)

# %% [markdown]
# 2. Create a graph that IS a subgraph of G (H1)

# %%
H1 = nx.Graph()
H1.add_edges_from([('A', 'C'), ('C', 'D')])
nx.draw(H1, with_labels=True)

# %% [markdown]
#   * Perform the checks

# %%
is_H1_subgraph = H1.subgraph(G)
print(is_H1_subgraph)
# Out:
# Graph with 3 nodes and 2 edges
